# %% [markdown]
# <a href="https://colab.research.google.com/github/siddheshDA/Retail_Dataset/blob/main/Retail_clean_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load raw data
df = pd.read_csv(r"/content/retail_raw_dataset (1).csv")

# 1. Remove duplicate rows
df.drop_duplicates(inplace=True)

# 2. Drop rows with critical missing values early
df.dropna(subset=['Full Name', 'Sales ($)', 'Email'], inplace=True)

# 3. Standardize text values
df['Gender'] = df['Gender'].str.strip().str.lower().replace({
    'm': 'Male', 'f': 'Female', 'male': 'Male', 'female': 'Female'
})
df['Country'] = df['Country'].str.strip().str.title()
df['Product Category'] = df['Product Category'].str.strip().str.title()

# 4. Convert date format to dd-mm-yyyy
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'], errors='coerce', dayfirst=True).dt.strftime('%d-%m-%Y')

# 5. Rename column headers
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# 6. Fix data types
df['age'] = pd.to_numeric(df['age'], errors='coerce')
df['sales_($)'] = pd.to_numeric(df['sales_($)'], errors='coerce')

# 7. Remove any remaining nulls to match strict task guidelines
df.dropna(inplace=True)

# Save cleaned file (optional)
df.to_csv("/content/retail_raw_dataset (1).csv", index=False)

# Show first 10 rows
df.head(100)
# Out:
#    customer_id             full_name  gender         country purchase_date  \
# 0        C1000          Allison Hill    Male           India    25-10-2024
# 1        C1001          Amanda Davis    Male   United States    29-10-2024
# 5        C1005          Jamie Arnold    Male   United States    04-06-2025
# 8        C1008           Joel Nelson  Female  United Kingdom    09-07-2025
# 13       C1013        Brittany Moore  Female  United Kingdom    11-04-2025
# 14       C1014       Tricia Valencia    Male           India    09-08-2024
# 15       C1015           Gina Carter    Male             Usa    01-10-2024
# 19       C1019            John Jones    Male       Singapore    10-05-2025
# 23       C1023        David Caldwell  Female       Singapore    22-10-2024
# 26       C1026           Connor West    Male   United States    06-01-2025
# 28       C1028          John Hancock    Male       Singapore    01-07-2025
# 36       C1036  Dr. Kendra Contreras    Male  United Kingdom    23-02-2025
# 37       C1037         Natalie Moore  Female             Usa    16-11-2024
# 50       C1050         Travis Mccall    Male       Singapore    21-03-2025
# 54       C1054     Bradley Robertson    Male             Usa    24-03-2025
# 55       C1055     Brittany Williams  Female           India    31-07-2025
# 59       C1059         Tiffany Vance  Female       Singapore    17-03-2025
# 73       C1073          Tina Sanders  Female             Usa    23-04-2025
# 77       C1077         Robert Medina  Female           India    28-01-2025
# 79       C1079         Jamie Johnson    Male   United States    12-06-2025
# 92       C1092        Benjamin Smith  Female       Singapore    16-01-2025
# 94       C1094       Danny Hernandez    Male       Singapore    10-11-2024
#
#    product_category   age  sales_($)                         email
# 0          Clothing  24.0     902.96    rhodespatricia@example.org
# 1          Clothing  19.0     744.42   hoffmanjennifer@example.net
# 5       Electronics  47.0     428.35         barbara10@example.net
# 8          Clothing  59.0     338.39  gabriellecameron@example.org
# 13       Home Decor  51.0     639.05       cruzcaitlin@example.com
# 14      Electronics  54.0     177.09   maldonadoamanda@example.com
# 15         Clothing  53.0     574.91        mckaynancy@example.com
# 19        Furniture  30.0     693.08      davidalvarez@example.net
# 23        Furniture  28.0     986.78      jenniferkhan@example.net
# 26      Electronics  33.0     947.44          steven17@example.net
# 28         Clothing  47.0     776.68  nicholasgalloway@example.com
# 36         Clothing  24.0     603.90    mcmillandennis@example.org
# 37         Clothing  29.0     122.31    jenniferharris@example.net
# 50         Clothing  51.0     601.67       cortezkevin@example.com
# 54         Clothing  27.0     157.81        clarence34@example.org
# 55        Furniture  55.0     117.58      gibsonolivia@example.net
# 59      Electronics  38.0     394.16            jrivas@example.com
# 73         Clothing  35.0     978.95       vargasmaria@example.org
# 77         Clothing  37.0     323.37         lpetersen@example.com
# 79         Clothing  60.0     315.88         tonykelly@example.com
# 92        Furniture  42.0     639.44           ocarter@example.com
# 94        Furniture  40.0     786.59     charlesmartin@example.com
